# %%
import wget

from ComplaintAnalizer import Clustering
from ComplaintAnalizer import clear_classes
from ComplaintAnalizer import clear_clusters
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tankist\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
url = 'https://data.gov.ru/opendata/7710349494-gosmonitor-review/data-20150923T1145-structure-20150923T1145.csv?encoding=UTF-8'
res = wget.download(url, 'datasets/clustering')
# Out:
#   5% [...                                                                     ]  1146880 / 20892640
#  12% [........                                                                ]  2605056 / 20892640
#  20% [..............                                                          ]  4333568 / 20892640
#  29% [.....................                                                   ]  6176768 / 20892640
#  37% [...........................                                             ]  7839744 / 20892640
#  45% [................................                                        ]  9568256 / 20892640
#  53% [......................................                                  ] 11247616 / 20892640
#  62% [.............................................                           ] 13131776 / 20892640
#  70% [..................................................                      ] 14712832 / 20892640
#  79% [.........................................................               ] 16662528 / 20892640
#  89% [................................................................        ] 18751488 / 20892640
#  99% [....................................................................... ] 20840448 / 20892640
# 100% [........................................................................] 20892640 / 20892640

# %%
print('Downloaded file: ' + res)
# Out:
# Downloaded file: datasets/clustering/data-20150923T1145-structure-20150923T1145 (1).csv
